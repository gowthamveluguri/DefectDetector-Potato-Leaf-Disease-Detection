# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import Xception
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import json
import os

# %%
# Paths
train_dir = r'/teamspace/studios/this_studio/mad/Dataset-MAD/train'
test_dir = r'/teamspace/studios/this_studio/mad/Dataset-MAD/test'
save_dir = r'/teamspace/studios/this_studio/model'

# %%
# Data Generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    validation_split=0.2
)
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(299, 299),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)
validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(299, 299),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(299, 299),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 1377 images belonging to 3 classes.
# Found 344 images belonging to 3 classes.
# Found 431 images belonging to 3 classes.

# %%
# Model Definition
base_model = Xception(weights='imagenet', include_top=False, input_shape=(299, 299, 3))
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.4)(x)  # Reduced Dropout
predictions = Dense(train_generator.num_classes, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=predictions)

# Compile and Train Model
for layer in base_model.layers:
    layer.trainable = False
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=8,  # Adjusted Epochs
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size
)
# Out:
# Epoch 1/8
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.6998 - loss: 0.6526 - val_accuracy: 0.9375 - val_loss: 0.2028
# Epoch 2/8
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8438 - loss: 0.3158 - val_accuracy: 0.7917 - val_loss: 0.4203
# Epoch 3/8
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9209 - loss: 0.2241 - val_accuracy: 0.9563 - val_loss: 0.1388
# Epoch 4/8
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9375 - loss: 0.1869 - val_accuracy: 0.9167 - val_loss: 0.1571
# Epoch 5/8
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.9584 - loss: 0.1374 - val_accuracy: 0.9719 - val_loss: 0.1029
# Epoch 6/8
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9688 - loss: 0.1296 - val_accuracy: 0.9167 - val_loss: 0.1319
# Epoch 7/8
# 2024-10-27 10:35:22.282385: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9647 - loss: 0.1095 - val_accuracy: 0.9594 - val_loss: 0.0952
# Epoch 8/8
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.9167 - val_loss: 0.0933

# %%
# Fine-Tune Last Few Layers
for layer in base_model.layers[-20:]:
    layer.trainable = True
model.compile(optimizer=Adam(learning_rate=1e-5),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=3,  # Adjusted Epochs
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size
)
# Out:
# Epoch 1/3
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - accuracy: 0.9238 - loss: 0.2031 - val_accuracy: 0.9625 - val_loss: 0.0722
# Epoch 2/3
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9688 - loss: 0.2422 - val_accuracy: 1.0000 - val_loss: 0.0694
# Epoch 3/3
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 100s 2s/step - accuracy: 0.9455 - loss: 0.1356 - val_accuracy: 0.9750 - val_loss: 0.0592

# %%
# Save Model for TFLite Conversion
model_save_path = os.path.join(save_dir, 'pdd.h5')
model.save(model_save_path)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Save the model in SavedModel format for TFLite conversion
model_save_path = os.path.join(save_dir, 'pdd')
model.export(model_save_path)  # Use export for SavedModel format

# Convert to TFLite with Quantization
converter = tf.lite.TFLiteConverter.from_saved_model(model_save_path)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()
tflite_model_save_path = os.path.join(save_dir, 'pdd.tflite')
with open(tflite_model_save_path, 'wb') as f:
    f.write(tflite_model)

print(f"TFLite model saved at {tflite_model_save_path}")
# Out:
# INFO:tensorflow:Assets written to: /teamspace/studios/this_studio/model/pdd/assets
# INFO:tensorflow:Assets written to: /teamspace/studios/this_studio/model/pdd/assets
# Saved artifact at '/teamspace/studios/this_studio/model/pdd'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name='keras_tensor_136')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   140693537894848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580758768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580760704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580756656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580759824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580766864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580765808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580768272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580756832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580767040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580797344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580794176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580797520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580799280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580796640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580798576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580788192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580801744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580755248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580854080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580856368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580853024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580853728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580789952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580792416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580788016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580791184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580861824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580865344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580903760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580902000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580902352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580905872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580912736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580902880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580864112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580912912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580914672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580912032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580913968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580863056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580865520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580861120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580864288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596740384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596737216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596740560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596742320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596739680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596741616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596730000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596830592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580900416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596829712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596832528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596829888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596831824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596731760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596734224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596729824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596732992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596841152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596841504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596828480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596827776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596840448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596837984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596826368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596914976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596914096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596916912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596914272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596916208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596923072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596923424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596912864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596912160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596922368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596919904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596910752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596998128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596997248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597000064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596997424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596999360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596994432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597003408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597088512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597088688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597004640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597088864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689596993904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597096432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597096608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597098368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597095728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597097664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580053200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580051616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580055312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580051440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580052848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689580054080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140690111340864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140690111340512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140690111347200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140690111343328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140690111336112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140690111344912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140690111334528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140690111342976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689602533808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689602541552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689602542432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689602536624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689602531872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689602533632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689602543312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689602536800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689602533280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689601285808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140690111338576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689601290208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689601289328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689601292144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689601289504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689601291440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689601297776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689601296016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598817984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689601293904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689601294256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598819040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689601283168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598810592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598809712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598812528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598809888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598811824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598823088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598815872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597099776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597099952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597100128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597092208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597094320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597103824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598466880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598469168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598465824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598466528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598476912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598465120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598477088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598478848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598476208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598478144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597103296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598649040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598648160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598650976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598648336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598650272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598657136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598647280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598657312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598659072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598656432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598658368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598644816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598551968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598551088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598553904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598551264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598553200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598560064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598548272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598560240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598562000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598559360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598561296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689598547744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597274016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597273136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597275952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597273312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597275248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597283344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597283696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597271904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597271200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597279648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597270320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597269792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597357168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597356288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597359104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597356464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597358400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597365264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597365616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597355056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597354352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597361568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597353472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597463040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597459872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597451248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597454768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597459344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597463392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597452656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597536864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597352944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597535984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597538800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597536160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597538096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597454416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597456880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597452480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597455648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597546192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597543904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597534752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597541792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597544080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597597120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597532640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597603632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597602752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597605568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597602928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597604864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597611200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689597599936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689595862528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140689595860240: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite model saved at /teamspace/studios/this_studio/model/pdd.tflite
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1730026489.136839    5467 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1730026489.137004    5467 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2024-10-27 10:54:49.137702: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /teamspace/studios/this_studio/model/pdd
# 2024-10-27 10:54:49.145374: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2024-10-27 10:54:49.145395: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /teamspace/studios/this_studio/model/pdd
# I0000 00:00:1730026489.207557    5467 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
# 2024-10-27 10:54:49.220990: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2024-10-27 10:54:49.758958: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /teamspace/studios/this_studio/model/pdd
# 2024-10-27 10:54:49.880012: I tensorflow/cc/saved_model/loader.cc:466] SavedModel load for tags { serve }; Status: success: OK. Took 742314 microseconds.
# 2024-10-27 10:54:50.001993: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.

# %%
# Save Class Indices as JSON for Kotlin Compatibility
class_indices_path = os.path.join(save_dir, 'class_indices.json')
with open(class_indices_path, 'w') as json_file:
    json.dump(train_generator.class_indices, json_file)

print(f"Model and class indices saved successfully in {save_dir}!")
# Out:
# Model and class indices saved successfully in /teamspace/studios/this_studio/model!
